# %%
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import IsolationForest
from drop_columns import DropColumns
from feature_interactions import FeatureInteractions
import joblib

# %%
fraud_data = pd.read_csv("cleaned_fraud_data.csv").drop(columns=["Unnamed: 0"])
fraud_data.head()
# Out:
#   transaction_id    user_id transaction_type   amount  location  \
# 0       TX100000  user_8270    Withdraw Cash  2646.35    Nakuru
# 1       TX100001  user_1860       Send Money  2844.69   Garissa
# 2       TX100002  user_6390     Deposit Cash  2384.46     Nyeri
# 3       TX100003  user_6191    Withdraw Cash  1846.01   Nairobi
# 4       TX100004  user_6734       Send Money  1017.60  Machakos
#
#      device_type network_provider   user_type  \
# 0  Feature Phone     Telkom Kenya  Individual
# 1            Ios        Safaricom       Agent
# 2  Feature Phone     Telkom Kenya       Agent
# 3            Ios        Safaricom  Individual
# 4  Feature Phone     Telkom Kenya  Individual
#
#   time_of_day(morning, afternoon, evening, night)  is_foreign_number  \
# 0                                         Evening                  0
# 1                                           Night                  0
# 2                                       Afternoon                  0
# 3                                           Night                  0
# 4                                           Night                  0
#
#    is_sim_recently_swapped  has_multiple_accounts             datetime  \
# 0                        0                      0  2024-06-16 21:45:13
# 1                        0                      0  2024-06-05 00:49:25
# 2                        0                      1  2024-06-13 15:54:02
# 3                        0                      1  2024-06-10 01:05:49
# 4                        0                      0  2024-06-27 02:28:53
#
#          date  hour
# 0  2024-06-16    21
# 1  2024-06-05     0
# 2  2024-06-13    15
# 3  2024-06-10     1
# 4  2024-06-27     2

# %%
# rename column
fraud_data = fraud_data.rename(columns={"time_of_day(morning, afternoon, evening, night)": "time_of_day"})

# %%
# Numerical columns to scale
cols_to_scale = ["amount_log", "transaction_frequency", "avg_amount_per_user", "fraud_risk_score"]
# Categorical Columns
categorical_cols = ['transaction_type', 'location', 'device_type', 'user_type']
# Binary Columns
binary_cols = ['is_foreign_number', 'is_sim_recently_swapped', 'has_multiple_accounts', 'night_transaction']

preprocessor = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), cols_to_scale),
        ('cat', OneHotEncoder(handle_unknown='ignore', drop="first"), categorical_cols),
        ('bin', 'passthrough', binary_cols)
    ]
)

# %%
X = fraud_data.copy()

# %%
model = Pipeline(steps=[
    ("feature_interactions", FeatureInteractions()),
    ("drop_columns", DropColumns(columns_to_drop=["transaction_id", "user_id", "amount", "network_provider",
                                            "time_of_day", "datetime", "date", "hour",
                                            "weighted_foreign", "weighted_sim_swap"])),
    ('preprocessor', preprocessor),
    ("classifier", IsolationForest(contamination=0.02, random_state=42))
])

model.fit(X)
# Out:
# Pipeline(steps=[('feature_interactions', FeatureInteractions()),
#                 ('drop_columns',
#                  DropColumns(columns_to_drop=['transaction_id', 'user_id',
#                                               'amount', 'network_provider',
#                                               'time_of_day', 'datetime', 'date',
#                                               'hour', 'weighted_foreign',
#                                               'weighted_sim_swap'])),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   ['amount_log',
#                                                    'transaction_frequency',
#                                                    'avg_amount_per_user',
#                                                    'fraud_risk_score']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['transaction_type',
#                                                    'location', 'device_type',
#                                                    'user_type']),
#                                                  ('bin', 'passthrough',
#                                                   ['is_foreign_number',
#                                                    'is_sim_recently_swapped',
#                                                    'has_multiple_accounts',
#                                                    'night_transaction'])])),
#                 ('classifier',
#                  IsolationForest(contamination=0.02, random_state=42))])

# %%
# save model
joblib.dump(model, "fraud_detection_model.pkl")
# Out:
# ['fraud_detection_model.pkl']

# %%
# Predict anomalies
fraud_data["anomaly_score"] = model.score_samples(X)
fraud_data["is_anomalous"] = model.predict(X)

# Display results
print("Anomaly Distribution:")
print(fraud_data["is_anomalous"].value_counts(normalize=True))

print("\nTop 10 Anomalous Transactions:")
display(fraud_data[fraud_data["is_anomalous"] == -1].sort_values("anomaly_score")[:-10])
# Out:
# Anomaly Distribution:
# is_anomalous
#  1    0.98
# -1    0.02
# Name: proportion, dtype: float64
#
# Top 10 Anomalous Transactions:
#      transaction_id    user_id transaction_type    amount location  \
# 4292       TX104292  user_9970     Deposit Cash  25058.95    Thika
# 284        TX100284  user_1980       Send Money  12767.11    Nyeri
# 1780       TX101780  user_6051   Lipa Na M-Pesa   2060.12    Nyeri
# 6150       TX106150  user_5305    Withdraw Cash   2208.80  Nairobi
# 662        TX100662  user_6115       Send Money   3000.92  Garissa
# ...             ...        ...              ...       ...      ...
# 76         TX100076  user_6276    Withdraw Cash   1228.73   Nakuru
# 6545       TX106545  user_5601    Withdraw Cash   6794.54    Nyeri
# 2838       TX102838  user_1182       Send Money    193.94  Garissa
# 7544       TX107544  user_5922     Deposit Cash   1857.52    Nyeri
# 2314       TX102314  user_1282   Lipa Na M-Pesa    143.10    Nyeri
#
#         device_type network_provider   user_type time_of_day  \
# 4292  Feature Phone     Telkom Kenya  Individual       Night
# 284             Ios        Safaricom       Agent       Night
# 1780            Ios           Airtel  Individual       Night
# 6150            Ios     Telkom Kenya  Individual       Night
# 662   Feature Phone     Telkom Kenya  Individual       Night
# ...             ...              ...         ...         ...
# 76              Ios           Airtel  Individual     Morning
# 6545            Ios        Safaricom  Individual   Afternoon
# 2838            Ios           Airtel       Agent     Morning
# 7544        Android        Safaricom  Individual       Night
# 2314        Android           Airtel  Individual       Night
#
#       is_foreign_number  is_sim_recently_swapped  has_multiple_accounts  \
# 4292                  1                        1                      0
# 284                   0                        1                      0
# 1780                  1                        1                      0
# 6150                  1                        0                      1
# 662                   1                        1                      0
# ...                 ...                      ...                    ...
# 76                    0                        1                      1
# 6545                  1                        0                      0
# 2838                  1                        0                      0
# 7544                  0                        1                      0
# 2314                  1                        0                      0
#
#                  datetime        date  hour  anomaly_score  is_anomalous
# 4292  2024-06-22 04:02:23  2024-06-22     4      -0.650268            -1
# 284   2024-06-11 03:37:11  2024-06-11     3      -0.619297            -1
# 1780  2024-06-14 01:47:33  2024-06-14     1      -0.618297            -1
# 6150  2024-06-20 04:28:01  2024-06-20     4      -0.612914            -1
# 662   2024-06-06 03:49:46  2024-06-06     3      -0.611327            -1
# ...                   ...         ...   ...            ...           ...
# 76    2024-06-17 08:56:21  2024-06-17     8      -0.558935            -1
# 6545  2024-06-25 13:10:44  2024-06-25    13      -0.558934            -1
# 2838  2024-06-08 06:49:32  2024-06-08     6      -0.558921            -1
# 7544  2024-06-08 04:14:51  2024-06-08     4      -0.558850            -1
# 2314  2024-06-04 04:09:09  2024-06-04     4      -0.558834            -1
#
# [190 rows x 17 columns]

# %%
import pandas as pd
import plotly.express as px
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True